# %% [markdown]
# ## 1. Project Information
# ============================================================
# ### FinSight AI
# ### Enterprise Financial News Intelligence Platform
# ### Notebook : 01_Project_Setup.ipynb
# ### Author   : Yanshu Patel
# ### Purpose  : Prepare the project environment.
# ============================================================

# %% [markdown]
# ## 2. Mount Google Drive

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 3. Install Libraries

# %%
# !pip install -q pandas
# !pip install -q numpy
# !pip install -q matplotlib
# !pip install -q seaborn
# !pip install -q pyarrow
# !pip install -q fastparquet
# !pip install -q tqdm
# !pip install -q plotly
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 50.8 MB/s eta 0:00:00

# %% [markdown]
# ## 4. Imports

# %%
import os
import random
import warnings

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from tqdm import tqdm

warnings.filterwarnings("ignore")

# %% [markdown]
# ## 5. Random Seed

# %%
SEED = 42

random.seed(SEED)
np.random.seed(SEED)

print("Random Seed:", SEED)
# Out:
# Random Seed: 42

# %% [markdown]
# ## 6. GPU Check

# %%
import torch

print("PyTorch Version :", torch.__version__)
print("GPU Available   :", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU Name :", torch.cuda.get_device_name(0))
# Out:
# PyTorch Version : 2.11.0+cpu
# GPU Available   : False

# %% [markdown]
# ## 7. Project Directory

# %%
PROJECT_ROOT = "/content/drive/MyDrive/FinSight_AI"

folders = [

    "data/raw",
    "data/interim",
    "data/processed",
    "data/features",
    "data/embeddings",

    "models",

    "graphs",

    "reports",

    "notebooks",

    "streamlit",

    "utils",

    "docs"

]

for folder in folders:

    os.makedirs(os.path.join(PROJECT_ROOT, folder), exist_ok=True)

print("Folders Created Successfully.")
# Out:
# Folders Created Successfully.

# %% [markdown]
# ## 8. Project Paths

# %%
RAW_DATA = os.path.join(PROJECT_ROOT, "data/raw")

INTERIM_DATA = os.path.join(PROJECT_ROOT, "data/interim")

PROCESSED_DATA = os.path.join(PROJECT_ROOT, "data/processed")

FEATURE_DATA = os.path.join(PROJECT_ROOT, "data/features")

EMBEDDING_DATA = os.path.join(PROJECT_ROOT, "data/embeddings")

MODEL_PATH = os.path.join(PROJECT_ROOT, "models")

GRAPH_PATH = os.path.join(PROJECT_ROOT, "graphs")

REPORT_PATH = os.path.join(PROJECT_ROOT, "reports")

# %% [markdown]
# ## 9. Verify Structure

# %%
print(PROJECT_ROOT)

for root, dirs, files in os.walk(PROJECT_ROOT):

    print(root)
# Out:
# /content/drive/MyDrive/FinSight_AI
# /content/drive/MyDrive/FinSight_AI
# /content/drive/MyDrive/FinSight_AI/data
# /content/drive/MyDrive/FinSight_AI/data/raw
# /content/drive/MyDrive/FinSight_AI/data/interim
# /content/drive/MyDrive/FinSight_AI/data/processed
# /content/drive/MyDrive/FinSight_AI/data/features
# /content/drive/MyDrive/FinSight_AI/data/embeddings
# /content/drive/MyDrive/FinSight_AI/models
# /content/drive/MyDrive/FinSight_AI/graphs
# /content/drive/MyDrive/FinSight_AI/reports
# /content/drive/MyDrive/FinSight_AI/notebooks
# /content/drive/MyDrive/FinSight_AI/streamlit
# /content/drive/MyDrive/FinSight_AI/utils
# /content/drive/MyDrive/FinSight_AI/docs

# %% [markdown]
# ## 10. Notebook Summary

# %%
print("="*60)

print("Project Setup Completed Successfully")

print("="*60)

print("Next Notebook")

print("02_Data_Loading.ipynb")
# Out:
# ...
# Project Setup Completed Successfully
# ...
# Next Notebook
# 02_Data_Loading.ipynb
